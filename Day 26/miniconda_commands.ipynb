# %% [markdown]
# # `Mini CONDA_3 Commads By Dr.Aammar:`

# %% [markdown]
# ### `yaha per base floor hoga, aur isi base floor ke ander ham bohot kuch kar saktei hai:`
#
# 1. conda env list
#
# ### `agar ham ne pakages dekhnei hai to ham ye wali command use karei ge:`
#
# 2. conda list
#
#    to ye saare pakages is ke ander already installed hai.
#
# ### `For updating the conda:`
#
# 3. conda update conda
#
# ### `For installing a Pakage:`
#
# 4. conda install [pakage name] = etc. conda install python
#
# ### `What if we have to Update a Pakage?`
#
# 5. conda update python
#
# ### `To check the purpose of a command:`
#
# 6. conda update --help
#
# ### `For Creating a Conda Environment :`
#
# 7. conda env list
# 8. conda create -n [name] , etc = conda create -n pandas_env `ham koi bhi naam rakh saktei hai`
# 9. conda env list  # for checking our new environment
# 10. conda activate pandas_env # same to same wahi spelling likhni hai.
# 11. conda deactivate pandas_env # for deactivating
#
# ### `Installing Python in the new environment:`
# 1. conda list
# 2. conda install python
#
# ### `Installing Libraries:`
# 1. pip install pandas.
# if we want to install list of libraries than
# 2. pip install pandas numpy seaborn matplotlib scikit-learn and so on without comma
#
# ### `Create copy of an Environment`:
# 1. conda create --clone pandas_env --name pandas_env2 # isko ham koi bhi naam de saktei hai
#
# ### `Changing the Directory:`
# 1. cd Desktop
# 2. make dir conda #--for making folder named conda
# 3. cd conda
# #--yaha per age ham ne apne environment ko text file mei save karna hai to phir ye wali command likhei
# 4. conda list --explicit > pandas_env.txt
#
# ### `For Installing many libraries at once from a text file:`
#    #--first of all we have to go to the file directory, and the use the following command:
#    1. conda install --yes --file req.txt
#
# ### `Making new Environment from a txt File`:
# #--Assignment:
# 1. pip install -r req.txt
# 2. conda --name shaheer_khan --file req.txt
# 3. pip freeze > req.txt
#
# ### `Install Pakages while creating an Environment:`
# 1. conda create -n jupyterKhan  jupyter  #-- where jupyter is the name of pakage to install while creating an Environment.
# 2. jupyter-notebook #--for running the jupyter notebook which we used in conda environment.
#
# ### `For Stoping the Command`:
# 1. ctrl+c or ctrl+\
#
# ### `For Removing Unwanted Environments:`
# 1. conda env list
# 2. conda env remove pandas_env2 jupyterKhan
#    #-- SO that the environments will be removed from the miniconda.
#
# ### `Removing Pakage from an Environment:`
# 1. conda remove --name base spyder
#
# ### `For Installing specific version pakage of Python or another thing:`
# 1. conda create -n py36 python=3.6
#    #--**if not working than we have to install tha channel in which that version of python will be available by the following command:**
# 2. conda create -n py36
# 3. conda activate py36
# 4. conda install --channel conda-forge python=3.6
#
# ### `Renaming the Conda Environment:`
# 1. conda create -name --pythonVer3.6 --clone py36
# 2. conda env list
# 3. conda env remove py34
#
# ### `Other purpose commands`:
# #--- for checking that where the python installed is located?:
# - `where python `
#
# #--- for installing specific version of pip pakage
# - `pip install numpy==1.11`
#
# #-- jo chezain ham ne pip se install ki hai usko ham conda se remove nahi kar saktei, that is the point to be noted.
#
# ham ye saari commands ko google me conda ki cheet sheet se dekh saktei hai.
#
# # `How to install Python Virtual Environment:`
# 1. python3 -m venv/path/to/virtual/environment
