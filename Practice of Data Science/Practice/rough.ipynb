# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/anony_khan/.local/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/anony_khan/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/anony_khan/.local/lib/python3.10/site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/anony_khan/.local/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/anony_khan/.local/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/anony_khan/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/anony_khan/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /home/anony_khan/.local/lib/python3.10/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
X = np.linspace(0, 2*np.pi, 100)
Y = np.cos(X)
fig, ax = plt.subplots()
ax.plot(X, Y, color='green')
fig.savefig("figure.pdf")
fig.show()
# Out:
# C:\Users\anony_khan\AppData\Local\Temp\ipykernel_7484\3507861704.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
