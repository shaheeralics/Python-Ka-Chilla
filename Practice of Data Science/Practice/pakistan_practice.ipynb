# %% [markdown]
# First of all I have to import data from exel sheet

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pak_data=pd.read_excel("pakistan.xls")

# %%
pak_data.head()
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2023-10-26 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#           Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                NaN             NaN          NaN          NaN          NaN
# 1                NaN             NaN          NaN          NaN          NaN
# 2     Indicator Name  Indicator Code       1960.0       1961.0       1962.0
# 3  Population, total     SP.POP.TOTL      54608.0      55811.0      56682.0
# 4  Population, total     SP.POP.TOTL  130692579.0  134169237.0  137835590.0
#
#     Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  Unnamed: 57  Unnamed: 58  \
# ...

# %%
pak_data.info
# Out:
# <bound method DataFrame.info of                      Data Source World Development Indicators  \
# 0              Last Updated Date          2023-10-26 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#             Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                  NaN             NaN          NaN          NaN          NaN
# ...

# %%
import pandas as pd

# %%
lahore = pd.read_clipboard()
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# /media/anony_khan/New Volume/Python Ka Chilla/Practice/pakistan_practice.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/media/anony_khan/New%20Volume/Python%20Ka%20Chilla/Practice/pakistan_practice.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> lahore = pd.read_clipboard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/clipboards.py:86, in read_clipboard(sep, dtype_backend, **kwargs)
#      83 from pandas.io.clipboard import clipboard_get
#      84 from pandas.io.parsers import read_csv
# ---> 86 text = clipboard_get()
#      88 # Try to decode (if needed, as "text" might already be a string here).
#      89 try:
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/clipboard/__init__.py:661, in lazy_load_stub_paste()
#     659 global copy, paste
#     660 copy, paste = determine_clipboard()
# --> 661 return paste()
# ...

# %%
lahore.info()

# %%
plt.figure(figsize=(30,30))
pakhan = sns.barplot(x='Province',y='Rank',hue='City',data=lahore)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already imported your data and set up the 'lahore' DataFrame

# Set the size of the plot
plt.figure(figsize=(30,30))
pakhan = sns.barplot(x='Province',y='Rank',hue='Population',data=lahore,width=5)

# Annotate the bars with city names
for p in pakhan.patches:
    pakhan.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Show the plot
plt.show()

# %% [markdown]
# # **Practice on the Pakistan Population Data:**
