# %% [markdown]
# <p align="center">
# _____________10 Mins To Pandas:_____________

# %% [markdown]
# ## First of all we import the libraries

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## **1_Basic Data Structures in Pandas:**
#
# Pandas provides two types of classes for handling data:
#
# 1. series:
#     >Series is one-dimensional labeled array holding data of any type suc as integers, strings, python objects etc.
#
# 1. Dataframe:
#     >Dataframe is a two-dimensional data structure that holds data like a two-dimentsion array or a table with rows and columns.

# %% [markdown]
# ## **2_Object Creations:**
# Creating a Series by passing a list of values, letting pandas create a default RangeIndex.

# %%
s= pd.Series([1,3,5,8,np.nan,10,223,np.nan,34])
s
# Out:
# 0      1.0
# 1      3.0
# 2      5.0
# 3      8.0
# 4      NaN
# 5     10.0
# 6    223.0
# 7      NaN
# 8     34.0
# dtype: float64

# %% [markdown]
# Creating a DataFrame by passing a Numpy array with a datetime index using date_range() and labeled columns:

# %%
dates = pd.date_range("20231124", periods=8)
dates
# Out:
# DatetimeIndex(['2023-11-24', '2023-11-25', '2023-11-26', '2023-11-27',
#                '2023-11-28', '2023-11-29', '2023-11-30', '2023-12-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
df= pd.DataFrame(np.random.randn(8,8), index = dates, columns=list('ABCDWXYZ'))
df
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691 -1.086937  0.639026
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
# 2023-11-29  1.889306  0.736479 -0.186489  0.312852 -0.430422  0.177862
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 -1.826240  0.934032
# 2023-12-01  0.659221  0.376306  1.240446 -2.206510 -0.950912 -1.512641
#
#                    Y         Z
# 2023-11-24 -0.249590 -0.367439
# 2023-11-25 -0.125636 -0.040830
# 2023-11-26 -1.523148  0.365213
# 2023-11-27 -1.272771  0.692215
# 2023-11-28  1.565049  0.962907
# 2023-11-29  0.018672  1.861714
# 2023-11-30 -0.307243 -1.359258
# 2023-12-01  0.667820 -0.356250

# %% [markdown]
# Creating a DataFrame by passing a dictionary of objects where the keys are the column labels and the values are the column values.

# %%
df3 = pd.DataFrame(
{
        "A" : 1.0,
        "Q" : pd.Timestamp("20231124"),
        "U" : pd.date_range("20231124", periods= 7),
        "I" : pd.Series(1,index=list(range(7)),dtype="float32"),
        "C" : np.array([3] * 7, dtype="int32"),
        "K" : pd.Categorical(["test","train", "test", "train","bus", "tractor", " Prado"]),
        "B" : "Byee!!!",
        
}
    
)
df3
# Out:
#      A          Q          U    I  C        K        B
# 0  1.0 2023-11-24 2023-11-24  1.0  3     test  Byee!!!
# 1  1.0 2023-11-24 2023-11-25  1.0  3    train  Byee!!!
# 2  1.0 2023-11-24 2023-11-26  1.0  3     test  Byee!!!
# 3  1.0 2023-11-24 2023-11-27  1.0  3    train  Byee!!!
# 4  1.0 2023-11-24 2023-11-28  1.0  3      bus  Byee!!!
# 5  1.0 2023-11-24 2023-11-29  1.0  3  tractor  Byee!!!
# 6  1.0 2023-11-24 2023-11-30  1.0  3    Prado  Byee!!!

# %% [markdown]
# The Columns of the resulting DataFrame have different dtypes:

# %%
df3.dtypes
# Out:
# A           float64
# Q     datetime64[s]
# U    datetime64[ns]
# I           float32
# C             int32
# K          category
# B            object
# dtype: object

# %% [markdown]
# ## **3_Viewing Data:**

# %% [markdown]
# Use `DataFrame.head()` and `DataFrame.tail()` to view the top and bottom rows of the frame respectively:

# %%
df.head()
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691 -1.086937  0.639026
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
#
#                    Y         Z
# 2023-11-24 -0.249590 -0.367439
# 2023-11-25 -0.125636 -0.040830
# 2023-11-26 -1.523148  0.365213
# 2023-11-27 -1.272771  0.692215
# 2023-11-28  1.565049  0.962907

# %%
df.tail()
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
# 2023-11-29  1.889306  0.736479 -0.186489  0.312852 -0.430422  0.177862
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 -1.826240  0.934032
# 2023-12-01  0.659221  0.376306  1.240446 -2.206510 -0.950912 -1.512641
#
#                    Y         Z
# 2023-11-27 -1.272771  0.692215
# 2023-11-28  1.565049  0.962907
# 2023-11-29  0.018672  1.861714
# 2023-11-30 -0.307243 -1.359258
# 2023-12-01  0.667820 -0.356250

# %% [markdown]
# Display the `DataFrame.index` or `DataFrame.columns` :

# %%
df.index
# Out:
# DatetimeIndex(['2023-11-24', '2023-11-25', '2023-11-26', '2023-11-27',
#                '2023-11-28', '2023-11-29', '2023-11-30', '2023-12-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'W', 'X', 'Y', 'Z'], dtype='object')

# %% [markdown]
# Retrun a NumPy representations of the underlying data with `DataFrame.to_numpy()` without the index or column labels:

# %%
df.to_numpy()
# Out:
# array([[ 0.14470557,  0.59196132,  0.10733809, -0.61539749, -0.90343282,
#         -1.1630597 , -0.24958959, -0.36743923],
#        [ 0.33064953, -0.0396252 ,  0.71831909,  0.07869147, -1.08693717,
#          0.63902623, -0.12563575, -0.04082977],
#        [-0.23597655,  0.15543151, -0.25163033, -0.3967849 , -0.09905972,
#         -0.17040641, -1.52314763,  0.36521265],
#        [ 0.00774138, -0.46334763, -0.52967275, -0.09280909, -0.56316921,
#         -0.06374029, -1.27277105,  0.69221487],
#        [ 0.06961771,  0.75740641, -0.02800381, -0.63317668, -0.87545455,
#          0.71637862,  1.56504942,  0.96290721],
#        [ 1.88930599,  0.73647934, -0.18648913,  0.31285155, -0.43042231,
#          0.1778618 ,  0.01867209,  1.86171399],
#        [ 1.51686316,  1.48267071,  0.68981895,  0.25124207, -1.82624036,
#          0.9340318 , -0.30724274, -1.35925804],
#        [ 0.65922149,  0.37630552,  1.24044555, -2.20650952, -0.95091209,
# ...

# %% [markdown]
# ### **` Note! `**
# NumPy arrays have one dtype for the entire array while pandas DataFrames have one dtype per column.
#
# When you call DataFrame.to_numpy(), pandas will find the NumPy dtype that can hold all of the dtypes in the DataFrame.
#
# If the common data type is object, DataFrame.to_numpy() will require copying data.

# %% [markdown]
# #### **`Example:`**

# %%
df3.dtypes
# Out:
# A           float64
# Q     datetime64[s]
# U    datetime64[ns]
# I           float32
# C             int32
# K          category
# B            object
# dtype: object

# %%
df3.to_numpy()
# Out:
# array([[1.0, Timestamp('2023-11-24 00:00:00'),
#         Timestamp('2023-11-24 00:00:00'), 1.0, 3, 'test', 'Byee!!!'],
#        [1.0, Timestamp('2023-11-24 00:00:00'),
#         Timestamp('2023-11-25 00:00:00'), 1.0, 3, 'train', 'Byee!!!'],
#        [1.0, Timestamp('2023-11-24 00:00:00'),
#         Timestamp('2023-11-26 00:00:00'), 1.0, 3, 'test', 'Byee!!!'],
#        [1.0, Timestamp('2023-11-24 00:00:00'),
#         Timestamp('2023-11-27 00:00:00'), 1.0, 3, 'train', 'Byee!!!'],
#        [1.0, Timestamp('2023-11-24 00:00:00'),
#         Timestamp('2023-11-28 00:00:00'), 1.0, 3, 'bus', 'Byee!!!'],
#        [1.0, Timestamp('2023-11-24 00:00:00'),
#         Timestamp('2023-11-29 00:00:00'), 1.0, 3, 'tractor', 'Byee!!!'],
#        [1.0, Timestamp('2023-11-24 00:00:00'),
#         Timestamp('2023-11-30 00:00:00'), 1.0, 3, ' Prado', 'Byee!!!']],
#       dtype=object)

# %% [markdown]
# So both Pandas `DataType` and Numpy `array` have dtype `Object`

# %% [markdown]
# ---
# `describe()` show a quick statistic summary of our data:

# %%
df.describe()
# Out:
#               A         B         C         D         W         X         Y  \
# count  8.000000  8.000000  8.000000  8.000000  8.000000  8.000000  8.000000
# mean   0.547766  0.449660  0.220016 -0.412737 -0.841954 -0.055319 -0.153356
# std    0.764891  0.589100  0.601693  0.812293  0.513334  0.884390  0.987057
# min   -0.235977 -0.463348 -0.529673 -2.206510 -1.826240 -1.512641 -1.523148
# 25%    0.054149  0.106667 -0.202774 -0.619842 -0.984918 -0.418570 -0.548625
# 50%    0.237678  0.484133  0.039667 -0.244797 -0.889444  0.057061 -0.187613
# 75%    0.873632  0.741711  0.696944  0.121829 -0.529982  0.658364  0.180959
# max    1.889306  1.482671  1.240446  0.312852 -0.099060  0.934032  1.565049
#
#               Z
# count  8.000000
# mean   0.219784
# std    0.980557
# min   -1.359258
# 25%   -0.359047
# 50%    0.162191
# 75%    0.759888
# max    1.861714

# %% [markdown]
# ---
#
# #### **Transposing Our Data:**

# %%
df.T
# Out:
#    2023-11-24  2023-11-25  2023-11-26  2023-11-27  2023-11-28  2023-11-29  \
# A    0.144706    0.330650   -0.235977    0.007741    0.069618    1.889306
# B    0.591961   -0.039625    0.155432   -0.463348    0.757406    0.736479
# C    0.107338    0.718319   -0.251630   -0.529673   -0.028004   -0.186489
# D   -0.615397    0.078691   -0.396785   -0.092809   -0.633177    0.312852
# W   -0.903433   -1.086937   -0.099060   -0.563169   -0.875455   -0.430422
# X   -1.163060    0.639026   -0.170406   -0.063740    0.716379    0.177862
# Y   -0.249590   -0.125636   -1.523148   -1.272771    1.565049    0.018672
# Z   -0.367439   -0.040830    0.365213    0.692215    0.962907    1.861714
#
#    2023-11-30  2023-12-01
# A    1.516863    0.659221
# B    1.482671    0.376306
# C    0.689819    1.240446
# D    0.251242   -2.206510
# W   -1.826240   -0.950912
# X    0.934032   -1.512641
# Y   -0.307243    0.667820
# Z   -1.359258   -0.356250

# %% [markdown]
# ---
# `DataFrame.sort_index()` sorts by an axis:
#
# If Axis is `0` it means `Rows` ( example is ka ye hai ke jab bande ka koi kaam nahi hota to wese hi leta para hota hai,
#
# jese ke rows leti hoti hai 😂)
#
# If Axis is `1` it means `Columns` ( example iska minar e Pakistan hai ke columns uski tarah khari hoti hai 😁)
#
# `By Dr. Aammar.`

# %%
df.sort_index(axis=0,ascending = False)  # is mei rows (0) ko kiya hai mene
# Out:
#                    A         B         C         D         W         X  \
# 2023-12-01  0.659221  0.376306  1.240446 -2.206510 -0.950912 -1.512641
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 -1.826240  0.934032
# 2023-11-29  1.889306  0.736479 -0.186489  0.312852 -0.430422  0.177862
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691 -1.086937  0.639026
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397 -0.903433 -1.163060
#
#                    Y         Z
# 2023-12-01  0.667820 -0.356250
# 2023-11-30 -0.307243 -1.359258
# 2023-11-29  0.018672  1.861714
# 2023-11-28  1.565049  0.962907
# 2023-11-27 -1.272771  0.692215
# 2023-11-26 -1.523148  0.365213
# 2023-11-25 -0.125636 -0.040830
# 2023-11-24 -0.249590 -0.367439

# %% [markdown]
# `DataFrame.sort_values` sorts by values:

# %%
df.sort_values(by='A')
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691 -1.086937  0.639026
# 2023-12-01  0.659221  0.376306  1.240446 -2.206510 -0.950912 -1.512641
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 -1.826240  0.934032
# 2023-11-29  1.889306  0.736479 -0.186489  0.312852 -0.430422  0.177862
#
#                    Y         Z
# 2023-11-26 -1.523148  0.365213
# 2023-11-27 -1.272771  0.692215
# 2023-11-28  1.565049  0.962907
# 2023-11-24 -0.249590 -0.367439
# 2023-11-25 -0.125636 -0.040830
# 2023-12-01  0.667820 -0.356250
# 2023-11-30 -0.307243 -1.359258
# 2023-11-29  0.018672  1.861714

# %% [markdown]
# ## **4_Selection:**

# %% [markdown]
# #### **`Note!`**
#
# While standard Python / NumPy expressions for selectiong and setting are intuitive and come in handy for interactive work , for production code, we recommend the optimized pandas data access methods, `DataFrame.at()`, `DataFrame.iat()`,`DataFrame.loc()`,and `DataFrame.iloc()`.
#
# ### `1_Getitem ([])`
# For a `DataFrame`, passing a single label selects a columns and yields a Series equivalent to ``df.A``:

# %%
df["A"]
# Out:
# 2023-11-24    0.144706
# 2023-11-25    0.330650
# 2023-11-26   -0.235977
# 2023-11-27    0.007741
# 2023-11-28    0.069618
# 2023-11-29    1.889306
# 2023-11-30    1.516863
# 2023-12-01    0.659221
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# For a `DataFrame`, passing a slice (`:`) selects matching rows :

# %%
df[0:3]
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691 -1.086937  0.639026
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
#
#                    Y         Z
# 2023-11-24 -0.249590 -0.367439
# 2023-11-25 -0.125636 -0.040830
# 2023-11-26 -1.523148  0.365213

# %%
df["20231124":"20231127"]
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691 -1.086937  0.639026
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
#
#                    Y         Z
# 2023-11-24 -0.249590 -0.367439
# 2023-11-25 -0.125636 -0.040830
# 2023-11-26 -1.523148  0.365213
# 2023-11-27 -1.272771  0.692215

# %% [markdown]
# ### `2_Selection By Label:`
#
# Selecting a row matching a label:

# %%
df.loc[dates[0]] # 0 is index number
# Out:
# A    0.144706
# B    0.591961
# C    0.107338
# D   -0.615397
# W   -0.903433
# X   -1.163060
# Y   -0.249590
# Z   -0.367439
# Name: 2023-11-24 00:00:00, dtype: float64

# %% [markdown]
# Selecting all rows (   `:`   ) with a select column labels:

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2023-11-24  0.144706  0.591961
# 2023-11-25  0.330650 -0.039625
# 2023-11-26 -0.235977  0.155432
# 2023-11-27  0.007741 -0.463348
# 2023-11-28  0.069618  0.757406
# 2023-11-29  1.889306  0.736479
# 2023-11-30  1.516863  1.482671
# 2023-12-01  0.659221  0.376306

# %%
df.loc[:,['C','D']]  # another example
# Out:
#                    C         D
# 2023-11-24  0.107338 -0.615397
# 2023-11-25  0.718319  0.078691
# 2023-11-26 -0.251630 -0.396785
# 2023-11-27 -0.529673 -0.092809
# 2023-11-28 -0.028004 -0.633177
# 2023-11-29 -0.186489  0.312852
# 2023-11-30  0.689819  0.251242
# 2023-12-01  1.240446 -2.206510

# %% [markdown]
# For label slicing, both endpoints are included:

# %%
df.loc["20231124":"20231127","A":"D"]
# Out:
#                    A         B         C         D
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809

# %% [markdown]
# Selecting a Single row and column label returns in scalar:

# %%
df.loc[dates[0],"A"]
# Out:
# 0.14470557163602982

# %% [markdown]
# For getting fast access to a scalar (equivalent to the prior method):

# %%
df.at[dates[0],"A"]
# Out:
# 0.14470557163602982

# %% [markdown]
# ### `3_Selection by position:`
#
# See more in [Selection by Position](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-integer)
# using [DataFrame.iloc()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html#pandas.DataFrame.iloc)
#  or [DataFrame.iat()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iat.html#pandas.DataFrame.iat).
#
# Selection via the position of last integers:

# %%
df.iloc[3]
# Out:
# A    0.007741
# B   -0.463348
# C   -0.529673
# D   -0.092809
# W   -0.563169
# X   -0.063740
# Y   -1.272771
# Z    0.692215
# Name: 2023-11-27 00:00:00, dtype: float64

# %% [markdown]
# Integer slices acts similar to NumPy/Python:

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2023-11-27  0.007741 -0.463348
# 2023-11-28  0.069618  0.757406

# %% [markdown]
# Lists of integer position locations:

# %%
df.iloc[[3,4,5],[2,4]]
# Out:
#                    C         W
# 2023-11-27 -0.529673 -0.563169
# 2023-11-28 -0.028004 -0.875455
# 2023-11-29 -0.186489 -0.430422

# %%
# example 2
df.iloc[[4],[4]]
# Out:
#                    W
# 2023-11-28 -0.875455

# %% [markdown]
# For slicing rows explicitly:

# %%
df.iloc[3:6,:]
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
# 2023-11-29  1.889306  0.736479 -0.186489  0.312852 -0.430422  0.177862
#
#                    Y         Z
# 2023-11-27 -1.272771  0.692215
# 2023-11-28  1.565049  0.962907
# 2023-11-29  0.018672  1.861714

# %%
df.iloc[:,2:5]
# Out:
#                    C         D         W
# 2023-11-24  0.107338 -0.615397 -0.903433
# 2023-11-25  0.718319  0.078691 -1.086937
# 2023-11-26 -0.251630 -0.396785 -0.099060
# 2023-11-27 -0.529673 -0.092809 -0.563169
# 2023-11-28 -0.028004 -0.633177 -0.875455
# 2023-11-29 -0.186489  0.312852 -0.430422
# 2023-11-30  0.689819  0.251242 -1.826240
# 2023-12-01  1.240446 -2.206510 -0.950912

# %% [markdown]
# For getting a value explicitly:

# %%
df.iloc[3,6]
# Out:
# -1.272771052643866

# %% [markdown]
# For getting fast access to a scalar (equivalent to the prior method):

# %%
df.iat[1,5]
# Out:
# 0.639026234580798

# %% [markdown]
# ### `4_Boolean indexing:`
#
# Select rows where `df.A` is greater than 0.

# %%
# this is only example the actual step is in below cell
df["A"]  # and df.A is same
# Out:
# 2023-11-24    0.144706
# 2023-11-25    0.330650
# 2023-11-26   -0.235977
# 2023-11-27    0.007741
# 2023-11-28    0.069618
# 2023-11-29    1.889306
# 2023-11-30    1.516863
# 2023-12-01    0.659221
# Freq: D, Name: A, dtype: float64

# %%
df[df["A"]>0.5]
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-29  1.889306  0.736479 -0.186489  0.312852 -0.430422  0.177862
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 -1.826240  0.934032
# 2023-12-01  0.659221  0.376306  1.240446 -2.206510 -0.950912 -1.512641
#
#                    Y         Z
# 2023-11-29  0.018672  1.861714
# 2023-11-30 -0.307243 -1.359258
# 2023-12-01  0.667820 -0.356250

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met:

# %%
df[df>0]
# Out:
#                    A         B         C         D   W         X         Y  \
# 2023-11-24  0.144706  0.591961  0.107338       NaN NaN       NaN       NaN
# 2023-11-25  0.330650       NaN  0.718319  0.078691 NaN  0.639026       NaN
# 2023-11-26       NaN  0.155432       NaN       NaN NaN       NaN       NaN
# 2023-11-27  0.007741       NaN       NaN       NaN NaN       NaN       NaN
# 2023-11-28  0.069618  0.757406       NaN       NaN NaN  0.716379  1.565049
# 2023-11-29  1.889306  0.736479       NaN  0.312852 NaN  0.177862  0.018672
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 NaN  0.934032       NaN
# 2023-12-01  0.659221  0.376306  1.240446       NaN NaN       NaN  0.667820
#
#                    Z
# 2023-11-24       NaN
# 2023-11-25       NaN
# 2023-11-26  0.365213
# 2023-11-27  0.692215
# 2023-11-28  0.962907
# 2023-11-29  1.861714
# 2023-11-30       NaN
# 2023-12-01       NaN

# %% [markdown]
# Using `isin()` method for filtering:

# %%
df4=df.copy()  # df4 me df ko mene copy kiya filhal

# %%
df4["E"] = ["one", "one", "two", "three", "four", "three","four","three"]
df4
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691 -1.086937  0.639026
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
# 2023-11-29  1.889306  0.736479 -0.186489  0.312852 -0.430422  0.177862
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 -1.826240  0.934032
# 2023-12-01  0.659221  0.376306  1.240446 -2.206510 -0.950912 -1.512641
#
#                    Y         Z      E
# 2023-11-24 -0.249590 -0.367439    one
# 2023-11-25 -0.125636 -0.040830    one
# 2023-11-26 -1.523148  0.365213    two
# 2023-11-27 -1.272771  0.692215  three
# 2023-11-28  1.565049  0.962907   four
# 2023-11-29  0.018672  1.861714  three
# 2023-11-30 -0.307243 -1.359258   four
# ...

# %%
df4[df4['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 -1.826240  0.934032
#
#                    Y         Z     E
# 2023-11-26 -1.523148  0.365213   two
# 2023-11-28  1.565049  0.962907  four
# 2023-11-30 -0.307243 -1.359258  four

# %% [markdown]
# ### `5_Setting:`
# Setting a new column automatically aligns the data by the indexes:

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"]=s1
df
# Out:
#                    A         B         C         D         W         X  \
# 2023-11-24  0.144706  0.591961  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.330650 -0.039625  0.718319  0.078691 -1.086937  0.639026
# 2023-11-26 -0.235977  0.155432 -0.251630 -0.396785 -0.099060 -0.170406
# 2023-11-27  0.007741 -0.463348 -0.529673 -0.092809 -0.563169 -0.063740
# 2023-11-28  0.069618  0.757406 -0.028004 -0.633177 -0.875455  0.716379
# 2023-11-29  1.889306  0.736479 -0.186489  0.312852 -0.430422  0.177862
# 2023-11-30  1.516863  1.482671  0.689819  0.251242 -1.826240  0.934032
# 2023-12-01  0.659221  0.376306  1.240446 -2.206510 -0.950912 -1.512641
#
#                    Y         Z   F
# 2023-11-24 -0.249590 -0.367439 NaN
# 2023-11-25 -0.125636 -0.040830 NaN
# 2023-11-26 -1.523148  0.365213 NaN
# 2023-11-27 -1.272771  0.692215 NaN
# 2023-11-28  1.565049  0.962907 NaN
# 2023-11-29  0.018672  1.861714 NaN
# 2023-11-30 -0.307243 -1.359258 NaN
# 2023-12-01  0.667820 -0.356250 NaN

# %% [markdown]
# Setting values by label:

# %%
df.at[dates[0], "A"] = 0
df.head(2)
# Out:
#                   A         B         C         D         W         X  \
# 2023-11-24  0.00000  0.591961  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.33065 -0.039625  0.718319  0.078691 -1.086937  0.639026
#
#                    Y         Z   F
# 2023-11-24 -0.249590 -0.367439 NaN
# 2023-11-25 -0.125636 -0.040830 NaN

# %% [markdown]
# Setting values by position:

# %%
df.iat[0, 1] = 0
df.head(2)
# Out:
#                   A         B         C         D         W         X  \
# 2023-11-24  0.00000  0.000000  0.107338 -0.615397 -0.903433 -1.163060
# 2023-11-25  0.33065 -0.039625  0.718319  0.078691 -1.086937  0.639026
#
#                    Y         Z   F
# 2023-11-24 -0.249590 -0.367439 NaN
# 2023-11-25 -0.125636 -0.040830 NaN

# %% [markdown]
# Setting by assigning with a NumPy array:

# %%
df.loc[:, "D"] = np.array([5,6,7,8,9,0,10,11] )
#   df.loc[:, "D"] = np.array([5] * len(df))    # ya phir ye method hai apni marzi hai
df.head()
# Out:
#                    A         B         C    D         W         X         Y  \
# 2023-11-24  0.000000  0.000000  0.107338  5.0 -0.903433 -1.163060 -0.249590
# 2023-11-25  0.330650 -0.039625  0.718319  6.0 -1.086937  0.639026 -0.125636
# 2023-11-26 -0.235977  0.155432 -0.251630  7.0 -0.099060 -0.170406 -1.523148
# 2023-11-27  0.007741 -0.463348 -0.529673  8.0 -0.563169 -0.063740 -1.272771
# 2023-11-28  0.069618  0.757406 -0.028004  9.0 -0.875455  0.716379  1.565049
#
#                    Z   F
# 2023-11-24 -0.367439 NaN
# 2023-11-25 -0.040830 NaN
# 2023-11-26  0.365213 NaN
# 2023-11-27  0.692215 NaN
# 2023-11-28  0.962907 NaN

# %% [markdown]
# A where operation with setting:

# %%
df5=df.copy()

# %%
df5[df5 > 0]=-df5
df5
# Out:
#                    A         B         C     D         W         X         Y  \
# 2023-11-24  0.000000  0.000000 -0.107338  -5.0 -0.903433 -1.163060 -0.249590
# 2023-11-25 -0.330650 -0.039625 -0.718319  -6.0 -1.086937 -0.639026 -0.125636
# 2023-11-26 -0.235977 -0.155432 -0.251630  -7.0 -0.099060 -0.170406 -1.523148
# 2023-11-27 -0.007741 -0.463348 -0.529673  -8.0 -0.563169 -0.063740 -1.272771
# 2023-11-28 -0.069618 -0.757406 -0.028004  -9.0 -0.875455 -0.716379 -1.565049
# 2023-11-29 -1.889306 -0.736479 -0.186489   0.0 -0.430422 -0.177862 -0.018672
# 2023-11-30 -1.516863 -1.482671 -0.689819 -10.0 -1.826240 -0.934032 -0.307243
# 2023-12-01 -0.659221 -0.376306 -1.240446 -11.0 -0.950912 -1.512641 -0.667820
#
#                    Z   F
# 2023-11-24 -0.367439 NaN
# 2023-11-25 -0.040830 NaN
# 2023-11-26 -0.365213 NaN
# 2023-11-27 -0.692215 NaN
# 2023-11-28 -0.962907 NaN
# 2023-11-29 -1.861714 NaN
# 2023-11-30 -1.359258 NaN
# 2023-12-01 -0.356250 NaN

# %% [markdown]
# ## **5_Missing data:**
#
# For NumPy data types, np.nan represents missing data. It is by default not included in computations. See the [Missing Data section](https://pandas.pydata.org/docs/user_guide/missing_data.html#missing-data).
#
#
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data:

# %%
df6=df.reindex(index=dates[0:7],columns=list(df.columns)+['G'])
df6.loc[dates[0]:dates[4],'G']=0.5
df6
# Out:
#                    A         B         C     D         W         X         Y  \
# 2023-11-24  0.000000  0.000000  0.107338   5.0 -0.903433 -1.163060 -0.249590
# 2023-11-25  0.330650 -0.039625  0.718319   6.0 -1.086937  0.639026 -0.125636
# 2023-11-26 -0.235977  0.155432 -0.251630   7.0 -0.099060 -0.170406 -1.523148
# 2023-11-27  0.007741 -0.463348 -0.529673   8.0 -0.563169 -0.063740 -1.272771
# 2023-11-28  0.069618  0.757406 -0.028004   9.0 -0.875455  0.716379  1.565049
# 2023-11-29  1.889306  0.736479 -0.186489   0.0 -0.430422  0.177862  0.018672
# 2023-11-30  1.516863  1.482671  0.689819  10.0 -1.826240  0.934032 -0.307243
#
#                    Z   F    G
# 2023-11-24 -0.367439 NaN  0.5
# 2023-11-25 -0.040830 NaN  0.5
# 2023-11-26  0.365213 NaN  0.5
# 2023-11-27  0.692215 NaN  0.5
# 2023-11-28  0.962907 NaN  0.5
# 2023-11-29  1.861714 NaN  NaN
# 2023-11-30 -1.359258 NaN  NaN

# %% [markdown]
# [DataFrame.dropna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html#pandas.DataFrame.dropna) drops any rows that have missing data:

# %%
df6.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, W, X, Y, Z, F, G]
# Index: []

# %% [markdown]
# [DataFrame.fillna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html#pandas.DataFrame.fillna) fills missing data:

# %%
df6.fillna(value=7)
# Out:
#                    A         B         C     D         W         X         Y  \
# 2023-11-24  0.000000  0.000000  0.107338   5.0 -0.903433 -1.163060 -0.249590
# 2023-11-25  0.330650 -0.039625  0.718319   6.0 -1.086937  0.639026 -0.125636
# 2023-11-26 -0.235977  0.155432 -0.251630   7.0 -0.099060 -0.170406 -1.523148
# 2023-11-27  0.007741 -0.463348 -0.529673   8.0 -0.563169 -0.063740 -1.272771
# 2023-11-28  0.069618  0.757406 -0.028004   9.0 -0.875455  0.716379  1.565049
# 2023-11-29  1.889306  0.736479 -0.186489   0.0 -0.430422  0.177862  0.018672
# 2023-11-30  1.516863  1.482671  0.689819  10.0 -1.826240  0.934032 -0.307243
#
#                    Z    F    G
# 2023-11-24 -0.367439  7.0  0.5
# 2023-11-25 -0.040830  7.0  0.5
# 2023-11-26  0.365213  7.0  0.5
# 2023-11-27  0.692215  7.0  0.5
# 2023-11-28  0.962907  7.0  0.5
# 2023-11-29  1.861714  7.0  7.0
# 2023-11-30 -1.359258  7.0  7.0

# %% [markdown]
# [isna()](https://pandas.pydata.org/docs/reference/api/pandas.isna.html#pandas.isna) gets the boolean mask where values are nan:

# %%
pd.isna(df6)
# Out:
#                 A      B      C      D      W      X      Y      Z     F  \
# 2023-11-24  False  False  False  False  False  False  False  False  True
# 2023-11-25  False  False  False  False  False  False  False  False  True
# 2023-11-26  False  False  False  False  False  False  False  False  True
# 2023-11-27  False  False  False  False  False  False  False  False  True
# 2023-11-28  False  False  False  False  False  False  False  False  True
# 2023-11-29  False  False  False  False  False  False  False  False  True
# 2023-11-30  False  False  False  False  False  False  False  False  True
#
#                 G
# 2023-11-24  False
# 2023-11-25  False
# 2023-11-26  False
# 2023-11-27  False
# 2023-11-28  False
# 2023-11-29   True
# 2023-11-30   True

# %% [markdown]
# ## **6_Operations**
# See the [Basic section on Binary Ops](https://pandas.pydata.org/docs/user_guide/basics.html#basics-binop).
#
# ### `1_Stats:`
# Operations in general exclude missing data.
#
# Calculate the mean value for each column:

# %%
df6.mean()
# Out:
# A    0.511172
# B    0.375574
# C    0.074240
# D    6.428571
# W   -0.826388
# X    0.152870
# Y   -0.270666
# Z    0.302075
# F         NaN
# G    0.500000
# dtype: float64

# %% [markdown]
# Calculate the mean value for each row:

# %%
df6.mean(axis=1)        # one rows ke lia hota hai
# Out:
# 2023-11-24    0.324869
# 2023-11-25    0.766107
# 2023-11-26    0.637825
# 2023-11-27    0.700806
# 2023-11-28    1.407545
# 2023-11-29    0.508390
# 2023-11-30    1.391330
# Freq: D, dtype: float64

# %% [markdown]
# Operating with another [```Series```](https://pandas.pydata.org/docs/reference/api/pandas.Series.html#pandas.Series) or
#  [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame) with a different index or column will align the result with the union of the index or column labels. In addition, pandas automatically broadcasts along the specified dimension and will fill unaligned labels with np.nan.

# %%
s = pd.Series([1,3,5,np.nan,9,11,13,15],index=dates).shift(2)
s
# Out:
# 2023-11-24     NaN
# 2023-11-25     NaN
# 2023-11-26     1.0
# 2023-11-27     3.0
# 2023-11-28     5.0
# 2023-11-29     NaN
# 2023-11-30     9.0
# 2023-12-01    11.0
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                     A          B         C    D          W          X  \
# 2023-11-24        NaN        NaN       NaN  NaN        NaN        NaN
# 2023-11-25        NaN        NaN       NaN  NaN        NaN        NaN
# 2023-11-26  -1.235977  -0.844568 -1.251630  6.0  -1.099060  -1.170406
# 2023-11-27  -2.992259  -3.463348 -3.529673  5.0  -3.563169  -3.063740
# 2023-11-28  -4.930382  -4.242594 -5.028004  4.0  -5.875455  -4.283621
# 2023-11-29        NaN        NaN       NaN  NaN        NaN        NaN
# 2023-11-30  -7.483137  -7.517329 -8.310181  1.0 -10.826240  -8.065968
# 2023-12-01 -10.340779 -10.623694 -9.759554  0.0 -11.950912 -12.512641
#
#                     Y          Z   F
# 2023-11-24        NaN        NaN NaN
# 2023-11-25        NaN        NaN NaN
# 2023-11-26  -2.523148  -0.634787 NaN
# 2023-11-27  -4.272771  -2.307785 NaN
# 2023-11-28  -3.434951  -4.037093 NaN
# 2023-11-29        NaN        NaN NaN
# 2023-11-30  -9.307243 -10.359258 NaN
# ...

# %% [markdown]
# ### `2_User defined functions:`
# [DataFrame.agg()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.agg.html#pandas.DataFrame.agg) and
# [DataFrame.transform()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transform.html#pandas.DataFrame.transform) applies a user defined function that reduces or broadcasts its result respectively.

# %%
df.agg(lambda x : np.mean(x) * 5.7 )    # df.mean()*5.7  # this is another form of code
# Out:
# A     3.019164
# B     2.141291
# C     1.254090
# D    39.900000
# W    -4.799135
# X    -0.315316
# Y    -0.874128
# Z     1.252769
# F          NaN
# dtype: float64

# %%
df.transform(lambda x : x*7)            # it means that every valye of df DataFrame is multiplied by 7
# Out:
#                     A          B         C     D          W          X  \
# 2023-11-24   0.000000   0.000000  0.751367  35.0  -6.324030  -8.141418
# 2023-11-25   2.314547  -0.277376  5.028234  42.0  -7.608560   4.473184
# 2023-11-26  -1.651836   1.088021 -1.761412  49.0  -0.693418  -1.192845
# 2023-11-27   0.054190  -3.243433 -3.707709  56.0  -3.942184  -0.446182
# 2023-11-28   0.487324   5.301845 -0.196027  63.0  -6.128182   5.014650
# 2023-11-29  13.225142   5.155355 -1.305424   0.0  -3.012956   1.245033
# 2023-11-30  10.618042  10.378695  4.828733  70.0 -12.783683   6.538223
# 2023-12-01   4.614550   2.634139  8.683119  77.0  -6.656385 -10.588489
#
#                     Y          Z   F
# 2023-11-24  -1.747127  -2.572075 NaN
# 2023-11-25  -0.879450  -0.285808 NaN
# 2023-11-26 -10.662033   2.556489 NaN
# 2023-11-27  -8.909397   4.845504 NaN
# 2023-11-28  10.955346   6.740350 NaN
# 2023-11-29   0.130705  13.031998 NaN
# 2023-11-30  -2.150699  -9.514806 NaN
# ...

# %% [markdown]
# ### `3_Value Counts:`
# See more at [Histogramming and Discretization](https://pandas.pydata.org/docs/user_guide/basics.html#basics-discretization).

# %%
k = pd.Series(np.random.randint(0,7,size=10))
k
# Out:
# 0    1
# 1    3
# 2    0
# 3    0
# 4    0
# 5    1
# 6    3
# 7    2
# 8    5
# 9    2
# dtype: int32

# %%
k.value_counts()
# Out:
# 0    3
# 1    2
# 3    2
# 2    2
# 5    1
# Name: count, dtype: int64

# %% [markdown]
# ### `4_String Methods:`
#
# [Series](https://pandas.pydata.org/docs/reference/api/pandas.Series.html#pandas.Series) is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. See more at [Vectorized String Methods](https://pandas.pydata.org/docs/user_guide/text.html#text-string-methods).

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## **7_Merge:**
# ### `1_Concat:`
# Pandas provides various facilities for easily combining together `Series` and `DataFrame` objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# See the [Merging section](https://pandas.pydata.org/docs/user_guide/merging.html#merging).
#
# Concatenating pandas objects together row-wise with [concat()](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat):

# %%
df8 = pd.DataFrame(np.random.randn(10, 4))
df8
# Out:
#           0         1         2         3
# 0  0.757409  1.171631  1.942621  1.147442
# 1  0.441644 -0.372690  0.439475  0.929156
# 2  1.168002  1.080301  0.103198  0.666898
# 3  1.882827  0.019567 -0.232163  0.258491
# 4 -1.532997 -1.307510  2.030629  0.575858
# 5  0.972696  0.883167  1.062577 -0.168177
# 6 -0.046922 -0.717867 -0.553476 -0.708075
# 7  1.065965 -1.416727 -0.894260 -0.386012
# 8  0.781588 -0.713902 -0.733080  0.704808
# 9  1.157661  0.040539  0.349409  0.516819

# %%
# Break it into pieces
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#                    A         B         C     D         W         X         Y  \
# 2023-11-24  0.000000  0.000000  0.107338   5.0 -0.903433 -1.163060 -0.249590
# 2023-11-25  0.330650 -0.039625  0.718319   6.0 -1.086937  0.639026 -0.125636
# 2023-11-26 -0.235977  0.155432 -0.251630   7.0 -0.099060 -0.170406 -1.523148
# 2023-11-27  0.007741 -0.463348 -0.529673   8.0 -0.563169 -0.063740 -1.272771
# 2023-11-28  0.069618  0.757406 -0.028004   9.0 -0.875455  0.716379  1.565049
# 2023-11-29  1.889306  0.736479 -0.186489   0.0 -0.430422  0.177862  0.018672
# 2023-11-30  1.516863  1.482671  0.689819  10.0 -1.826240  0.934032 -0.307243
# 2023-12-01  0.659221  0.376306  1.240446  11.0 -0.950912 -1.512641  0.667820
#
#                    Z   F
# 2023-11-24 -0.367439 NaN
# 2023-11-25 -0.040830 NaN
# 2023-11-26  0.365213 NaN
# 2023-11-27  0.692215 NaN
# 2023-11-28  0.962907 NaN
# 2023-11-29  1.861714 NaN
# 2023-11-30 -1.359258 NaN
# 2023-12-01 -0.356250 NaN

# %% [markdown]
# > Note!
# >
# > - Adding a column to a [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame) is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the `DataFrame` constructor instead of building a `DataFrame` by iteratively appending records to it.
#
# ### `2_Join:`
# [merge()](https://pandas.pydata.org/docs/reference/api/pandas.merge.html#pandas.merge) enables SQL style join types along specific columns. See the [Database style joining](https://pandas.pydata.org/docs/user_guide/merging.html#merging-join) section.

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# merge() on unique keys:

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left , right, on = 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## **8_Grouping:**
# By “group by” we are referring to a process involving one or more of the following steps:
#
# - **Splitting** the data into groups based on some criteria
#
# - **Applying** a function to each group independently
#
# - **Combining** the results into a data structure
#
# See the [Grouping Section](https://pandas.pydata.org/docs/user_guide/groupby.html#groupby).

# %%
df9 = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8)
    }
)

# %%
df9
# Out:
#      A      B         C         D
# 0  foo    one  0.205349  0.951255
# 1  bar    one -1.148587 -0.200935
# 2  foo    two  0.627404  0.108467
# 3  bar  three -0.818919 -0.849468
# 4  foo    two -1.274655  0.972361
# 5  bar    two  1.856774 -0.961912
# 6  foo    one -1.801031  0.676156
# 7  foo  three  0.138600 -0.016064

# %% [markdown]
# Grouping by a column label, selecting column labels, and then applying the
# [sum()](https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.sum.html#pandas.core.groupby.DataFrameGroupBy.sum)
# function to the resulting groups:

# %%
df9.groupby("A")[["C", "D"]].sum() # what does sum() do here in this code df.groupby("A")[["C", "D"]].sum()?
# Out:
#             C         D
# A
# bar -0.110732 -2.012316
# foo -2.104333  2.692174

# %%
df9.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.148587 -0.200935
#     three -0.818919 -0.849468
#     two    1.856774 -0.961912
# foo one   -1.595682  1.627411
#     three  0.138600 -0.016064
#     two   -0.647251  1.080828

# %%
df9.groupby(["A","B"])[["C"]].sum() # what does sum() do here in this code df.groupby("A")[["C", "D"]].sum()?
# Out:
#                   C
# A   B
# bar one   -1.148587
#     three -0.818919
#     two    1.856774
# foo one   -1.595682
#     three  0.138600
#     two   -0.647251

# %% [markdown]
# ## **9_Reshaping:**
# See the sections on [Hierarchical Indexing](https://pandas.pydata.org/docs/user_guide/advanced.html#advanced-hierarchical) and [Reshaping](https://pandas.pydata.org/docs/user_guide/reshaping.html#reshaping-stacking).
#
# ### `1_Stack:`

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

df10 = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df11 = df10[:4]

df11
# Out:
#                      A         B
# first second
# bar   one     0.905912  0.137179
#       two     0.725266 -1.225859
# baz   one     1.986946  1.009878
#       two    -0.122260  0.094779

# %% [markdown]
# The [stack()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html#pandas.DataFrame.stack) method “compresses” a level in the DataFrame’s columns:

# %%
stacked = df11.stack(future_stack=True)
stacked
# Out:
# first  second
# bar    one     A    0.905912
#                B    0.137179
#        two     A    0.725266
#                B   -1.225859
# baz    one     A    1.986946
#                B    1.009878
#        two     A   -0.122260
#                B    0.094779
# dtype: float64

# %% [markdown]
# With a “stacked” DataFrame or Series (having a [MultiIndex](https://pandas.pydata.org/docs/reference/api/pandas.MultiIndex.html#pandas.MultiIndex) as the index), the inverse operation of [stack()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html#pandas.DataFrame.stack) is [unstack()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.unstack.html#pandas.DataFrame.unstack), which by default unstacks the **last level**:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.905912  0.137179
#       two     0.725266 -1.225859
# baz   one     1.986946  1.009878
#       two    -0.122260  0.094779

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.905912  0.725266
#       B  0.137179 -1.225859
# baz   A  1.986946 -0.122260
#       B  1.009878  0.094779

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.905912  1.986946
#        B  0.137179  1.009878
# two    A  0.725266 -0.122260
#        B -1.225859  0.094779

# %% [markdown]
# ### `2_Pivot tables:`
# See the section on [Pivot Tables](https://pandas.pydata.org/docs/user_guide/reshaping.html#reshaping-pivot).

# %%
df12 = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df12
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.627190  0.848893
# 1     one  B  foo  1.758401 -0.622830
# 2     two  C  foo -0.999521 -0.690438
# 3   three  A  bar  0.639055  1.098242
# 4     one  B  bar  1.174303 -0.063933
# 5     one  C  bar  0.603238 -0.316883
# 6     two  A  foo -0.197178 -1.109543
# 7   three  B  foo  0.479975  0.471775
# 8     one  C  foo -0.265956 -1.230409
# 9     one  A  bar -0.936268  0.920713
# 10    two  B  bar -2.311161 -2.355076
# 11  three  C  bar  0.116000  1.042216

# %% [markdown]
# [pivot_table()](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html#pandas.pivot_table) pivots a [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame) specifying the `values`, `index` and `columns`

# %%
# method 1:
pd.pivot_table(df12, values=["D","E"], index=["A", "B"], columns=["C"])
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A -0.936268  0.627190  0.920713  0.848893
#       B  1.174303  1.758401 -0.063933 -0.622830
#       C  0.603238 -0.265956 -0.316883 -1.230409
# three A  0.639055       NaN  1.098242       NaN
#       B       NaN  0.479975       NaN  0.471775
#       C  0.116000       NaN  1.042216       NaN
# two   A       NaN -0.197178       NaN -1.109543
#       B -2.311161       NaN -2.355076       NaN
#       C       NaN -0.999521       NaN -0.690438

# %%
# method 2:
pd.pivot_table(df12, values=["D","E"], index=["A", "B","C"])
# Out:
#                     D         E
# A     B C
# one   A bar -0.936268  0.920713
#         foo  0.627190  0.848893
#       B bar  1.174303 -0.063933
#         foo  1.758401 -0.622830
#       C bar  0.603238 -0.316883
#         foo -0.265956 -1.230409
# three A bar  0.639055  1.098242
#       B foo  0.479975  0.471775
#       C bar  0.116000  1.042216
# two   A foo -0.197178 -1.109543
#       B bar -2.311161 -2.355076
#       C foo -0.999521 -0.690438

# %% [markdown]
# ## **10_Time Series:**
# Pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial applications. See the [Time Series section](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries)

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index= rng)

ts.resample("5Min").sum()
# Out:
# 2012-01-01    22987
# Freq: 5T, dtype: int32

# %% [markdown]
# [Series.tz_localize()](https://pandas.pydata.org/docs/reference/api/pandas.Series.tz_localize.html#pandas.Series.tz_localize) localizes a time series to a time zone:

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-03-06   -0.437658
# 2012-03-07   -0.821924
# 2012-03-08   -1.156981
# 2012-03-09    0.538864
# 2012-03-10    0.710353
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.437658
# 2012-03-07 00:00:00+00:00   -0.821924
# 2012-03-08 00:00:00+00:00   -1.156981
# 2012-03-09 00:00:00+00:00    0.538864
# 2012-03-10 00:00:00+00:00    0.710353
# Freq: D, dtype: float64

# %% [markdown]
# [Series.tz_convert()](https://pandas.pydata.org/docs/reference/api/pandas.Series.tz_convert.html#pandas.Series.tz_convert) converts a timezones aware time series to another time zone:

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.437658
# 2012-03-06 19:00:00-05:00   -0.821924
# 2012-03-07 19:00:00-05:00   -1.156981
# 2012-03-08 19:00:00-05:00    0.538864
# 2012-03-09 19:00:00-05:00    0.710353
# Freq: D, dtype: float64

# %% [markdown]
# Adding a non-fixed duration ([BusinessDay](https://pandas.pydata.org/docs/reference/api/pandas.tseries.offsets.BusinessDay.html#pandas.tseries.offsets.BusinessDay)) to a time series:

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## **11_Categoricals:**
# Pandas can include categorical data in a DataFrame. For full docs, see the [categorical introduction](https://pandas.pydata.org/docs/user_guide/categorical.html#categorical) and the [API documentation](https://pandas.pydata.org/docs/reference/arrays.html#api-arrays-categorical).

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under Series.cat() return a new Series by default):

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)


df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %% [markdown]
# Sorting is per order in the categories, not lexical order:

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## **12_Plotting:**
# [Plotting](https://pandas.pydata.org/docs/user_guide/visualization.html#visualization)
# See the Plotting docs.
#
# We use the standard convention for referencing the matplotlib API:

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %% [markdown]
# The plt.close method is used to [close](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.close.html) a figure window:

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %% [markdown]
# >Note!
# >- When using Jupyter, the plot will appear using plot(). Otherwise use [matplotlib.pyplot.show](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.show.html) to show it or [matplotlib.pyplot.savefig](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html) to write it to a file.

# %% [markdown]
# [plot()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot) plots all columns:

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)


df = df.cumsum()

plt.figure();

df.plot();

plt.legend(loc='best');

# %% [markdown]
# ## **13_Importing and exporting data:**
# See the [IO Tools](https://pandas.pydata.org/docs/user_guide/io.html#io) section.
# ### `1_CSV:`
# [Writing to a csv](https://pandas.pydata.org/docs/user_guide/io.html#io-store-in-csv) file: using [DataFrame.to_csv()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html#pandas.DataFrame.to_csv)

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

# %% [markdown]
# [Reading from a csv](https://pandas.pydata.org/docs/user_guide/io.html#io-read-csv-table) file: using [read_csv()](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html#pandas.read_csv)

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  2  2  3  0  1
# 1           1  0  0  0  3  2
# 2           2  2  1  2  1  4
# 3           3  4  3  0  3  4
# 4           4  0  2  3  1  3
# 5           5  4  3  1  2  3
# 6           6  3  1  3  0  0
# 7           7  4  0  3  1  3
# 8           8  3  4  2  1  3
# 9           9  2  3  3  1  0

# %% [markdown]
# ### `2_Parquet:`
# Writing to a Parquet file:

# %% [markdown]
# pip install fastparquet

# %%
pip install pyarrow
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pyarrow in c:\users\anony_khan\appdata\local\programs\python\python311\lib\site-packages (14.0.1)
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#df.to_parquet("foo.parquet")

# %% [markdown]
# ### `3_Excel:`
# Reading and writing to [Excel](https://pandas.pydata.org/docs/user_guide/io.html#io-excel).
#
# Writing to an excel file using [DataFrame.to_excel()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html#pandas.DataFrame.to_excel):

# %% [markdown]
# Reading from an excel file using [read_excel()](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html#pandas.read_excel):

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  2  2  3  0  1
# 1           1  0  0  0  3  2
# 2           2  2  1  2  1  4
# 3           3  4  3  0  3  4
# 4           4  0  2  3  1  3
# 5           5  4  3  1  2  3
# 6           6  3  1  3  0  0
# 7           7  4  0  3  1  3
# 8           8  3  4  2  1  3
# 9           9  2  3  3  1  0

# %% [markdown]
# ## **14_Gotchas:**
# If you are attempting to perform a boolean operation on a Series or DataFrame you might see an exception like:

# %%
if pd.Series([False, True, False]):
     print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7732\3390390655.py in ?()
# ----> 1 if pd.Series([False, True, False]):
#       2      print("I was true")
#
# c:\Users\anony_khan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# See [Comparisons](https://pandas.pydata.org/docs/user_guide/basics.html#basics-compare) and [Gotchas](https://pandas.pydata.org/docs/user_guide/gotchas.html#gotchas) for an explanation and what to do.
